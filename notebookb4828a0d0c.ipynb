# %%
# !git clone https://github.com/AliTavana99/FPT.git
# Out:
# fatal: destination path 'FPT' already exists and is not an empty directory.

# %%
# !git -C FPT pull
# Out:
# Already up to date.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:09
# 🔁 Restarting kernel...

# %%
# !conda create -n fpt_py313 python=3.13 -y
# !conda run -n fpt_py313 python --version
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/fpt_py313
#
#   added / updated specs:
#     - python=3.13
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.1.31  |       hbd8a1cb_1         155 KB  conda-forge
#     ld_impl_linux-64-2.43      |       h712a8e2_4         656 KB  conda-forge
#     libexpat-2.7.0             |       h5888daf_0          73 KB  conda-forge
#     libffi-3.4.6               |       h2dba641_1          56 KB  conda-forge
#     libgcc-14.2.0              |       h767d61c_2         828 KB  conda-forge
# ...

# %%
# !conda run -n fpt_py313 pip install -r FPT/requirements.txt
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 34.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 51.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 38.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 87.0 MB/s eta 0:00:00
# ...

# %%
# !ls /kaggle/input/labeled-chest-xray-images/chest_xray
# Out:
# test  train

# %%
# !conda run -n fpt_py313 python FPT/my_data.py
# Out:
# Setting up dataset from /kaggle/input/labeled-chest-xray-images/chest_xray to /kaggle/working/labeled-chest-xray-images
#
# Dataset setup complete. File counts:
#
# TRAIN SET:
#   NORMAL: 1349 files
#   PNEUMONIA: 3883 files
#   TOTAL: 5232 files
#
# VALIDATION SET:
#   NORMAL: 55 files
#   PNEUMONIA: 58 files
#   TOTAL: 113 files
#
# TEST SET:
#   NORMAL: 199 files
#   PNEUMONIA: 332 files
#   TOTAL: 531 files
#
# 2025-04-23 07:43:34,043 - INFO - Found classes: ['PNEUMONIA', 'NORMAL']
# 2025-04-23 07:43:34,043 - INFO - Created directory: /kaggle/working/labeled-chest-xray-images/train/PNEUMONIA
# 2025-04-23 07:43:34,043 - INFO - Created directory: /kaggle/working/labeled-chest-xray-images/train/NORMAL
# 2025-04-23 07:43:34,043 - INFO - Created directory: /kaggle/working/labeled-chest-xray-images/validation/PNEUMONIA
# 2025-04-23 07:43:34,043 - INFO - Created directory: /kaggle/working/labeled-chest-xray-images/validation/NORMAL
# ...

# %%
# !ls /kaggle/working/labeled-chest-xray-images
# Out:
# test  train  validation

# %%
# !conda run -n fpt_py313 python FPT/preload.py dataset=chest_X_ray
# Out:
# Preloading covid dataset...
# Preloading train dataset...
#
# /kaggle/working/FPT/preload.py:15: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="configs", config_name="config")
# /usr/local/envs/fpt_py313/lib/python3.13/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
#
# ...
#  50%|████▉     | 162/327 [02:59<03:02,  1.11s/it]
# Error executing job with overrides: ['dataset=chest_X_ray']
# Traceback (most recent call last):
#   File "/kaggle/working/FPT/preload.py", line 26, in main
#     preload_dataset(cfg, dataset, frozen_encoder)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !conda run -n fpt_py313 python FPT/main.py dataset=chest_X_ray
# Out:
# ^C

# %%
# !conda run -n fpt_py313 python -m pip freeze
# Out:
# antlr4-python3-runtime==4.9.3
# certifi==2025.1.31
# charset-normalizer==3.4.1
# filelock==3.18.0
# fsspec==2025.3.2
# huggingface-hub==0.30.2
# hydra-core==1.3.2
# idna==3.10
# Jinja2==3.1.6
# MarkupSafe==3.0.2
# mpmath==1.3.0
# networkx==3.4.2
# numpy==2.2.5
# nvidia-cublas-cu12==12.4.5.8
# nvidia-cuda-cupti-cu12==12.4.127
# nvidia-cuda-nvrtc-cu12==12.4.127
# nvidia-cuda-runtime-cu12==12.4.127
# nvidia-cudnn-cu12==9.1.0.70
# nvidia-cufft-cu12==11.2.1.3
# nvidia-curand-cu12==10.3.5.147
# nvidia-cusolver-cu12==11.6.1.9
# nvidia-cusparse-cu12==12.3.1.170
# nvidia-cusparselt-cu12==0.6.2
# nvidia-nccl-cu12==2.21.5
# nvidia-nvjitlink-cu12==12.4.127
# nvidia-nvtx-cu12==12.4.127
# omegaconf==2.3.0
# packaging==25.0
# pillow==11.2.1
# PyYAML==6.0.2
# regex==2024.11.6
# requests==2.32.3
# safetensors==0.5.3
# setuptools==79.0.0
# sympy==1.13.1
# tokenizers==0.21.1
# torch==2.6.0
# torcheval==0.0.7
# torchvision==0.21.0
# tqdm==4.67.1
# transformers==4.51.3
# triton==3.2.0
# ...
